# %% [markdown]
# Demo 9: String Manipulation
# Name: Rovin Castelino
# Registration Number: 240957001
# PC 46
# 22/3/25

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("examples/sentiment.csv", index_col=0)
df
# Out:
#                                                   Text    Sentiment  \
# ID
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 728  Collaborating on a science project that receiv...       Happy
# 729  Attending a surprise birthday party organized ...       Happy
# 730  Successfully fundraising for a school charity ...       Happy
# 731  Participating in a multicultural festival, cel...       Happy
# 732  Organizing a virtual talent show during challe...       Happy
#
#             Timestamp                                   User     Platform  \
# ID
# 0    15-01-2023 12:30                          User123          Twitter
# ...

# %% [markdown]
# 1. In the sentiment feature and text, trim white spaces and convert to lowercase.

# %%
df['Sentiment']=df['Sentiment'].str.strip().str.lower()
df['Text']=df['Text'].str.strip().str.lower()
df
# Out:
#                                                   Text Sentiment  \
# ID
# 0                enjoying a beautiful day at the park!  positive
# 1                   traffic was terrible this morning.  negative
# 2                  just finished an amazing workout! 💪  positive
# 3          excited about the upcoming weekend getaway!  positive
# 4          trying out a new recipe for dinner tonight.   neutral
# ..                                                 ...       ...
# 728  collaborating on a science project that receiv...     happy
# 729  attending a surprise birthday party organized ...     happy
# 730  successfully fundraising for a school charity ...     happy
# 731  participating in a multicultural festival, cel...     happy
# 732  organizing a virtual talent show during challe...     happy
#
#             Timestamp                                   User     Platform  \
# ID
# 0    15-01-2023 12:30                          User123          Twitter
# ...

# %% [markdown]
# 2. What are the sentiment categories? Tabulate and visualize the number of texts for each category.

# %%
df['Sentiment'].unique()
# Out:
# array(['positive', 'negative', 'neutral', 'anger', 'fear', 'sadness',
#        'disgust', 'happiness', 'joy', 'love', 'amusement', 'enjoyment',
#        'admiration', 'affection', 'awe', 'disappointed', 'surprise',
#        'acceptance', 'adoration', 'anticipation', 'bitter', 'calmness',
#        'confusion', 'excitement', 'kind', 'pride', 'shame', 'elation',
#        'euphoria', 'contentment', 'serenity', 'gratitude', 'hope',
#        'empowerment', 'compassion', 'tenderness', 'arousal', 'enthusiasm',
#        'fulfillment', 'reverence', 'despair', 'grief', 'loneliness',
#        'jealousy', 'resentment', 'frustration', 'boredom', 'anxiety',
#        'intimidation', 'helplessness', 'envy', 'regret', 'curiosity',
#        'indifference', 'numbness', 'melancholy', 'nostalgia',
#        'ambivalence', 'determination', 'zest', 'hopeful', 'proud',
#        'grateful', 'empathetic', 'compassionate', 'playful',
#        'free-spirited', 'inspired', 'confident', 'bitterness', 'yearning',
# ...

# %%
df['Sentiment'].nunique()
# Out:
# 191

# %%
tab = df.groupby('Sentiment')['Text'].count().sort_values(ascending = False).head(10)
plt.figure(figsize=(15,5))
sns.barplot(x = tab.index, y= tab.values)
# Out:
# <Axes: xlabel='Sentiment'>

# %% [markdown]
# The bar graph shows the number of texts for each sentiment category, with positive and joy having the highest counts and despair having the lowest.

# %% [markdown]
# 3. Tabulate and Visualize the text length for each sentiment category.

# %%
df['Text_length'] = df['Text'].apply(len)
text = df.groupby('Sentiment')['Text_length'].mean().sort_values(ascending = False).head(10)
plt.figure(figsize = (20,6))
sns.barplot(x=text.index, y= text.values)
# Out:
# <Axes: xlabel='Sentiment'>

# %% [markdown]
# The bar graph shows the number of texts for each sentiment category, with "winter magic" having the highest count and other categories having slightly lower but similar counts.

# %% [markdown]
# 4. Find and display the text(s) with the maximum number of likes.

# %%
tab = df.groupby('Text')['Likes'].sum().sort_values(ascending = False).head(10)
plt.figure(figsize = (10,6))
sns.barplot(y= tab.index, x = tab.values)
# Out:
# <Axes: ylabel='Text'>

# %% [markdown]
# The bar graph shows the texts with the highest number of likes, where the top text has the most likes, and the rest follow in descending order

# %% [markdown]
# 5. Find and display the text(s) with the maximum reposts. what is its sentiment?

# %%
tab = df.groupby('Text')['Retweets'].sum().sort_values(ascending = False).head(10)
plt.figure(figsize = (10,6))
sns.barplot(y= tab.index, x = tab.values)
# Out:
# <Axes: ylabel='Text'>

# %% [markdown]
# The bar graph shows the top 10 texts with the highest retweets, ranked in descending order.

# %% [markdown]
# 6. Tabulate and Visualize the top 5 countries that have posted the most texts with a positive sentiment.

# %%
tab = df[df['Sentiment']=='positive'].groupby('Country')['Sentiment'].count().sort_values(ascending = False).head(5)
sns.barplot(x = tab.index, y = tab.values)
# Out:
# <Axes: xlabel='Country'>

# %% [markdown]
# The bar graph displays the top 5 countries that posted the most texts with a positive sentiment, with India and the USA having the highest counts.

# %% [markdown]
# 7. Find and display all the text(s) with the word ‘Travel’ in their hashtag.

# %%
tab = df[df['Hashtags'].str.contains('Travel')]
tab
# Out:
#                                                   Text   Sentiment  \
# ID
# 3          excited about the upcoming weekend getaway!    positive
# 73   excitement building up for the upcoming vacation!  excitement
# 85   enjoying every moment of this trip—pure enjoym...   enjoyment
# 146  arousal of excitement before a much-awaited trip.     arousal
# 597  spontaneously booked a weekend getaway. advent...  excitement
# 611  embarked on a road trip to revisit cherished p...         joy
# 623  embarked on a solo travel adventure, discoveri...  excitement
#
#             Timestamp               User     Platform  \
# ID
# 3    15-01-2023 18:20      AdventureX       Facebook
# 73   18-02-2023 18:45   VacationDreamer     Facebook
# 85   23-02-2023 19:45   TravelExplorer      Facebook
# 146  10-03-2018 09:45   TravelExcitement    Twitter
# 597  05-06-2023 10:00   AdventureSeeker    Instagram
# 611  19-06-2023 16:30    RoadTripSenior     Facebook
# ...

# %% [markdown]
# 8. Find and display the most popular (most number of likes) posts (top 5) from the year
# 2020 which were of a negative sentiment.

# %%
tab = df[(df['Year']==2020) & (df['Sentiment']=='negative')]
tab
# Out:
# Empty DataFrame
# Columns: [Text, Sentiment, Timestamp, User, Platform, Hashtags, Retweets, Likes, Country, Year, Month, Day, Hour, Text_length]
# Index: []

# %% [markdown]
# 9. Find and display a list of Users and their posts whose texts are labeled ‘Happiness’ sentiment

# %%
tab = df[df['Sentiment']=='happy']
tab
# Out:
#                                                   Text Sentiment  \
# ID
# 719  celebrating a friend's birthday with a surpris...     happy
# 720  successfully completing a challenging coding p...     happy
# 721  attending a school talent show to support clas...     happy
# 722  exploring a new hiking trail with friends over...     happy
# 723  winning a friendly sports competition against ...     happy
# 724  receiving a heartfelt letter from a pen pal in...     happy
# 725  creating a beautiful mural with fellow art ent...     happy
# 726  participating in a school-wide art exhibition....     happy
# 727  achieving a personal best in a track and field...     happy
# 728  collaborating on a science project that receiv...     happy
# 729  attending a surprise birthday party organized ...     happy
# 730  successfully fundraising for a school charity ...     happy
# 731  participating in a multicultural festival, cel...     happy
# ...

# %% [markdown]
# 10. Tabulate and visualize the years and countrywide tweets of the sentiments. Pick tweets with sentiments, ‘Positive,’ ‘Negative,’ and ‘Neutral’ only.

# %%
year_country_data = df[['Year','Country','Sentiment']][(df['Sentiment'] == 'positive') |(df['Sentiment'] == 'negative') |(df['Sentiment'] == 'neutral') ]
print(year_country_data['Year'].unique())
year_country_data['Country'] = year_country_data['Country'].str.strip()
sns.barplot(x=year_country_data['Sentiment'].value_counts().index,y=year_country_data['Sentiment'].value_counts().values)
plt.title('Sentiment Distribution in 2023')
plt.show()
print('Sentiment distribution for 2023')
year_country_data['Sentiment'].value_counts()
fig, ax = plt.subplots(figsize=(10, 6))
country_data = year_country_data.drop('Year',axis=1).groupby('Country')['Sentiment'].value_counts().plot(kind='bar',ax=ax)
plt.title('Country wise Sentiment Distribution')
plt.ylabel('Count')
plt.xlabel('Country')
plt.show()
# Out:
# [2023]
# Sentiment distribution for 2023

# %% [markdown]
# 1. Sentiment Distribution in 2023: Most tweets were positive, followed by neutral and negative.
# 2. Country-wise Sentiment Distribution: The USA had the highest number of positive tweets, with other countries showing a mix of sentiments.
